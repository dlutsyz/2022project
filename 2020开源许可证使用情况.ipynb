# %%
import requests

#MIT
# 执行API调用并存储响应
url = 'https://api.github.com/search/repositories?q=created:2020+license:mit'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# 将API响应赋给一个变量
response_dict = r.json()
count2020MIT = response_dict['total_count']
print(f"Total repositories: {count2020MIT}")

#Apache
# 执行API调用并存储响应
url = 'https://api.github.com/search/repositories?q=created:2020+license:apache-2.0'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# 将API响应赋给一个变量
response_dict = r.json()
count2020Apache = response_dict['total_count']
print(f"Total repositories: {count2020Apache}")

#GPL3.0
# 执行API调用并存储响应
url = 'https://api.github.com/search/repositories?q=created:2020+license:gpl-3.0'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# 将API响应赋给一个变量
response_dict = r.json()
count2020GPL3 = response_dict['total_count']
print(f"Total repositories: {count2020GPL3}")

#GPL2.0
# 执行API调用并存储响应
url = 'https://api.github.com/search/repositories?q=created:2020+license:gpl-2.0'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# 将API响应赋给一个变量
response_dict = r.json()
count2020GPL2 = response_dict['total_count']
print(f"Total repositories: {count2020GPL2}")

#BSD3
# 执行API调用并存储响应
url = 'https://api.github.com/search/repositories?q=created:2020+license:bsd-3-clause'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# 将API响应赋给一个变量
response_dict = r.json()
count2020BSD3 = response_dict['total_count']
print(f"Total repositories: {count2020BSD3}")

#BSD2
# 执行API调用并存储响应
url = 'https://api.github.com/search/repositories?q=created:2020+license:bsd-2-clause'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# 将API响应赋给一个变量
response_dict = r.json()
count2020BSD2 = response_dict['total_count']
print(f"Total repositories: {count2020BSD2}")

#CCO
# 执行API调用并存储响应
url = 'https://api.github.com/search/repositories?q=created:2020+license:cc0-1.0'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# 将API响应赋给一个变量
response_dict = r.json()
count2020CCO = response_dict['total_count']
print(f"Total repositories: {count2020CCO}")

#AGPL
# 执行API调用并存储响应
url = 'https://api.github.com/search/repositories?q=created:2020+license:agpl-3.0'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# 将API响应赋给一个变量
response_dict = r.json()
count2020AGPL = response_dict['total_count']
print(f"Total repositories: {count2020AGPL}")

#LGPL
# 执行API调用并存储响应
url = 'https://api.github.com/search/repositories?q=created:2020+license:lgpl-3.0'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# 将API响应赋给一个变量
response_dict = r.json()
count2020LGPL = response_dict['total_count']
print(f"Total repositories: {count2020LGPL}")

#MPL
# 执行API调用并存储响应
url = 'https://api.github.com/search/repositories?q=created:2020+license:mpl-2.0'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# 将API响应赋给一个变量
response_dict = r.json()
count2020MPL = response_dict['total_count']
print(f"Total repositories: {count2020MPL}")
# Out:
# Status code: 200
# Total repositories: 1705038
# Status code: 200
# Total repositories: 300465
# Status code: 200
# Total repositories: 318766
# Status code: 200
# Total repositories: 32699
# Status code: 200
# Total repositories: 44337
# Status code: 200
# Total repositories: 13317
# Status code: 200
# Total repositories: 29402
# Status code: 200
# Total repositories: 26618
# Status code: 200
# Total repositories: 11086
# Status code: 200
# Total repositories: 14120

# %%
L2 = [count2020MIT,count2020Apache,count2020GPL3,count2020GPL2,count2020BSD3,count2020BSD2,count2020CCO,count2020AGPL,count2020LGPL,count2020MPL]
L1 = ['mit','apache-2.0','gpl-3.0','gpl-2.0','bsd-3-clause','bsd-2-clause','cc0-1.0','agpl-3.0','lgpl-3.0','mpl-2.0']

# %%
# 验证数据是否正确
repo_dicts = response_dict['items']
print(f"Repositories returned: {len(repo_dicts)}")

print("\n部分仓库的信息:")
for repo_dict in repo_dicts:
    print(f"\nName: {repo_dict['name']}")
    print(f"Owner: {repo_dict['owner']['login']}")
    print(f"License: {repo_dict['license']}")
    print(f"Created: {repo_dict['created_at']}")
    print(f"Updated: {repo_dict['updated_at']}")
#可以看出这些都是使用了对应年份的对应许可证的项目
# Out:
# Repositories returned: 30
#
# 部分仓库的信息:
#
# Name: helix
# Owner: helix-editor
# License: {'key': 'mpl-2.0', 'name': 'Mozilla Public License 2.0', 'spdx_id': 'MPL-2.0', 'url': 'https://api.github.com/licenses/mpl-2.0', 'node_id': 'MDc6TGljZW5zZTE0'}
# Created: 2020-06-01T04:26:56Z
# Updated: 2022-11-27T11:35:04Z
#
# Name: GHunt
# Owner: mxrch
# License: {'key': 'mpl-2.0', 'name': 'Mozilla Public License 2.0', 'spdx_id': 'MPL-2.0', 'url': 'https://api.github.com/licenses/mpl-2.0', 'node_id': 'MDc6TGljZW5zZTE0'}
# Created: 2020-10-02T11:26:03Z
# Updated: 2022-11-27T11:05:14Z
#
# Name: dev-sidecar
# Owner: docmirror
# License: {'key': 'mpl-2.0', 'name': 'Mozilla Public License 2.0', 'spdx_id': 'MPL-2.0', 'url': 'https://api.github.com/licenses/mpl-2.0', 'node_id': 'MDc6TGljZW5zZTE0'}
# Created: 2020-09-29T10:38:20Z
# Updated: 2022-11-27T11:42:23Z
#
# Name: Xray-core
# Owner: XTLS
# License: {'key': 'mpl-2.0', 'name': 'Mozilla Public License 2.0', 'spdx_id': 'MPL-2.0', 'url': 'https://api.github.com/licenses/mpl-2.0', 'node_id': 'MDc6TGljZW5zZTE0'}
# Created: 2020-11-09T11:23:10Z
# Updated: 2022-11-27T12:35:28Z
#
# Name: earthly
# Owner: earthly
# License: {'key': 'mpl-2.0', 'name': 'Mozilla Public License 2.0', 'spdx_id': 'MPL-2.0', 'url': 'https://api.github.com/licenses/mpl-2.0', 'node_id': 'MDc6TGljZW5zZTE0'}
# Created: 2020-03-12T18:24:04Z
# Updated: 2022-11-27T10:40:35Z
#
# Name: TTS
# Owner: coqui-ai
# License: {'key': 'mpl-2.0', 'name': 'Mozilla Public License 2.0', 'spdx_id': 'MPL-2.0', 'url': 'https://api.github.com/licenses/mpl-2.0', 'node_id': 'MDc6TGljZW5zZTE0'}
# Created: 2020-05-20T15:45:28Z
# Updated: 2022-11-27T07:51:55Z
#
# Name: waypoint
# Owner: hashicorp
# License: {'key': 'mpl-2.0', 'name': 'Mozilla Public License 2.0', 'spdx_id': 'MPL-2.0', 'url': 'https://api.github.com/licenses/mpl-2.0', 'node_id': 'MDc6TGljZW5zZTE0'}
# Created: 2020-04-27T03:08:12Z
# Updated: 2022-11-27T08:32:02Z
#
# Name: terraform-cdk
# Owner: hashicorp
# License: {'key': 'mpl-2.0', 'name': 'Mozilla Public License 2.0', 'spdx_id': 'MPL-2.0', 'url': 'https://api.github.com/licenses/mpl-2.0', 'node_id': 'MDc6TGljZW5zZTE0'}
# Created: 2020-01-08T16:13:45Z
# Updated: 2022-11-27T03:05:23Z
#
# Name: boundary
# Owner: hashicorp
# License: {'key': 'mpl-2.0', 'name': 'Mozilla Public License 2.0', 'spdx_id': 'MPL-2.0', 'url': 'https://api.github.com/licenses/mpl-2.0', 'node_id': 'MDc6TGljZW5zZTE0'}
# Created: 2020-01-08T18:24:07Z
# Updated: 2022-11-26T14:30:46Z
#
# Name: cloudquery
# Owner: cloudquery
# License: {'key': 'mpl-2.0', 'name': 'Mozilla Public License 2.0', 'spdx_id': 'MPL-2.0', 'url': 'https://api.github.com/licenses/mpl-2.0', 'node_id': 'MDc6TGljZW5zZTE0'}
# Created: 2020-11-18T07:16:21Z
# Updated: 2022-11-26T23:36:23Z
#
# Name: oicq
# Owner: takayama-lily
# License: {'key': 'mpl-2.0', 'name': 'Mozilla Public License 2.0', 'spdx_id': 'MPL-2.0', 'url': 'https://api.github.com/licenses/mpl-2.0', 'node_id': 'MDc6TGljZW5zZTE0'}
# Created: 2020-08-05T04:39:20Z
# Updated: 2022-11-27T12:32:51Z
#
# Name: hubris
# Owner: oxidecomputer
# License: {'key': 'mpl-2.0', 'name': 'Mozilla Public License 2.0', 'spdx_id': 'MPL-2.0', 'url': 'https://api.github.com/licenses/mpl-2.0', 'node_id': 'MDc6TGljZW5zZTE0'}
# Created: 2020-04-02T00:06:32Z
# Updated: 2022-11-24T10:30:05Z
#
# Name: ledge
# Owner: phodal
# License: {'key': 'mpl-2.0', 'name': 'Mozilla Public License 2.0', 'spdx_id': 'MPL-2.0', 'url': 'https://api.github.com/licenses/mpl-2.0', 'node_id': 'MDc6TGljZW5zZTE0'}
# Created: 2020-03-09T08:29:22Z
# Updated: 2022-11-25T01:42:08Z
#
# Name: Traduzir-paginas-web
# Owner: FilipePS
# License: {'key': 'mpl-2.0', 'name': 'Mozilla Public License 2.0', 'spdx_id': 'MPL-2.0', 'url': 'https://api.github.com/licenses/mpl-2.0', 'node_id': 'MDc6TGljZW5zZTE0'}
# Created: 2020-02-15T16:54:52Z
# Updated: 2022-11-27T12:10:31Z
#
# Name: QuickCut
# Owner: HaujetZhao
# License: {'key': 'mpl-2.0', 'name': 'Mozilla Public License 2.0', 'spdx_id': 'MPL-2.0', 'url': 'https://api.github.com/licenses/mpl-2.0', 'node_id': 'MDc6TGljZW5zZTE0'}
# Created: 2020-07-25T09:33:29Z
# Updated: 2022-11-26T02:36:30Z
#
# Name: next-mdx-remote
# Owner: hashicorp
# License: {'key': 'mpl-2.0', 'name': 'Mozilla Public License 2.0', 'spdx_id': 'MPL-2.0', 'url': 'https://api.github.com/licenses/mpl-2.0', 'node_id': 'MDc6TGljZW5zZTE0'}
# Created: 2020-04-23T00:07:26Z
# Updated: 2022-11-25T16:22:39Z
#
# Name: Tachidesk-Server
# Owner: Suwayomi
# License: {'key': 'mpl-2.0', 'name': 'Mozilla Public License 2.0', 'spdx_id': 'MPL-2.0', 'url': 'https://api.github.com/licenses/mpl-2.0', 'node_id': 'MDc6TGljZW5zZTE0'}
# Created: 2020-12-23T20:31:38Z
# Updated: 2022-11-27T12:24:55Z
#
# Name: leapp
# Owner: Noovolari
# License: {'key': 'mpl-2.0', 'name': 'Mozilla Public License 2.0', 'spdx_id': 'MPL-2.0', 'url': 'https://api.github.com/licenses/mpl-2.0', 'node_id': 'MDc6TGljZW5zZTE0'}
# Created: 2020-07-28T07:54:59Z
# Updated: 2022-11-26T12:41:20Z
#
# Name: DDoS-Ripper
# Owner: palahsu
# License: {'key': 'mpl-2.0', 'name': 'Mozilla Public License 2.0', 'spdx_id': 'MPL-2.0', 'url': 'https://api.github.com/licenses/mpl-2.0', 'node_id': 'MDc6TGljZW5zZTE0'}
# Created: 2020-10-16T13:06:45Z
# Updated: 2022-11-26T16:24:22Z
#
# Name: procedural-gl-js
# Owner: felixpalmer
# License: {'key': 'mpl-2.0', 'name': 'Mozilla Public License 2.0', 'spdx_id': 'MPL-2.0', 'url': 'https://api.github.com/licenses/mpl-2.0', 'node_id': 'MDc6TGljZW5zZTE0'}
# Created: 2020-11-19T09:25:13Z
# Updated: 2022-11-23T09:53:19Z
#
# Name: featureform
# Owner: featureform
# License: {'key': 'mpl-2.0', 'name': 'Mozilla Public License 2.0', 'spdx_id': 'MPL-2.0', 'url': 'https://api.github.com/licenses/mpl-2.0', 'node_id': 'MDc6TGljZW5zZTE0'}
# Created: 2020-10-16T05:41:53Z
# Updated: 2022-11-27T02:08:03Z
#
# Name: uniffi-rs
# Owner: mozilla
# License: {'key': 'mpl-2.0', 'name': 'Mozilla Public License 2.0', 'spdx_id': 'MPL-2.0', 'url': 'https://api.github.com/licenses/mpl-2.0', 'node_id': 'MDc6TGljZW5zZTE0'}
# Created: 2020-06-10T07:36:02Z
# Updated: 2022-11-27T04:46:12Z
#
# Name: rust-design-pattern
# Owner: lpxxn
# License: {'key': 'mpl-2.0', 'name': 'Mozilla Public License 2.0', 'spdx_id': 'MPL-2.0', 'url': 'https://api.github.com/licenses/mpl-2.0', 'node_id': 'MDc6TGljZW5zZTE0'}
# Created: 2020-02-26T03:26:00Z
# Updated: 2022-11-26T15:30:23Z
#
# Name: unvcode
# Owner: RimoChan
# License: {'key': 'mpl-2.0', 'name': 'Mozilla Public License 2.0', 'spdx_id': 'MPL-2.0', 'url': 'https://api.github.com/licenses/mpl-2.0', 'node_id': 'MDc6TGljZW5zZTE0'}
# Created: 2020-11-30T15:13:43Z
# Updated: 2022-11-27T11:51:14Z
#
# Name: cocoa
# Owner: cocoa-mhlw
# License: {'key': 'mpl-2.0', 'name': 'Mozilla Public License 2.0', 'spdx_id': 'MPL-2.0', 'url': 'https://api.github.com/licenses/mpl-2.0', 'node_id': 'MDc6TGljZW5zZTE0'}
# Created: 2020-08-12T02:51:24Z
# Updated: 2022-11-27T09:13:58Z
#
# Name: starboard-notebook
# Owner: gzuidhof
# License: {'key': 'mpl-2.0', 'name': 'Mozilla Public License 2.0', 'spdx_id': 'MPL-2.0', 'url': 'https://api.github.com/licenses/mpl-2.0', 'node_id': 'MDc6TGljZW5zZTE0'}
# Created: 2020-07-23T14:39:29Z
# Updated: 2022-11-25T08:02:25Z
#
# Name: setup-terraform
# Owner: hashicorp
# License: {'key': 'mpl-2.0', 'name': 'Mozilla Public License 2.0', 'spdx_id': 'MPL-2.0', 'url': 'https://api.github.com/licenses/mpl-2.0', 'node_id': 'MDc6TGljZW5zZTE0'}
# Created: 2020-04-23T16:53:07Z
# Updated: 2022-11-26T20:33:30Z
#
# Name: learn4haskell
# Owner: kowainik
# License: {'key': 'mpl-2.0', 'name': 'Mozilla Public License 2.0', 'spdx_id': 'MPL-2.0', 'url': 'https://api.github.com/licenses/mpl-2.0', 'node_id': 'MDc6TGljZW5zZTE0'}
# Created: 2020-09-26T09:44:33Z
# Updated: 2022-11-27T09:49:48Z
#
# Name: TidGi-Desktop
# Owner: tiddly-gittly
# License: {'key': 'mpl-2.0', 'name': 'Mozilla Public License 2.0', 'spdx_id': 'MPL-2.0', 'url': 'https://api.github.com/licenses/mpl-2.0', 'node_id': 'MDc6TGljZW5zZTE0'}
# Created: 2020-06-12T10:59:18Z
# Updated: 2022-11-27T11:12:23Z
#
# Name: StyLua
# Owner: JohnnyMorganz
# License: {'key': 'mpl-2.0', 'name': 'Mozilla Public License 2.0', 'spdx_id': 'MPL-2.0', 'url': 'https://api.github.com/licenses/mpl-2.0', 'node_id': 'MDc6TGljZW5zZTE0'}
# Created: 2020-12-15T21:24:43Z
# Updated: 2022-11-27T09:01:23Z

# %%
from plotly import offline

# 可视化
data = [{
    'type': 'bar',
    'x': L1,
    'y': L2,   
    'marker': {
        'color': 'rgb(100, 140, 200)',
        'line': {'width': 1, 'color': 'rgb(10, 10, 10)'}
    },
    'opacity': 0.5,
}]

my_layout = {
    'title': '2020GitHub开源许可证的使用',
    'titlefont': {'size': 20},
    'xaxis': {
        'title': '开源许可证',
        'titlefont': {'size': 20},
        'tickfont': {'size': 10},
    },
    'yaxis': {
        'title': '仓库数',
        'titlefont': {'size': 20},
        'tickfont': {'size': 10},
    },

}

fig = {'data': data, 'layout': my_layout}
offline.plot(fig, filename='2020.html')
# Out:
# '2020.html'
