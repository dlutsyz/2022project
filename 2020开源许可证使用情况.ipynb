# %%
import requests

#MIT
# 执行API调用并存储响应
url = 'https://api.github.com/search/repositories?q=created:2020&q=license:mit'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# 将API响应赋给一个变量
response_dict = r.json()
count2020MIT = response_dict['total_count']
print(f"Total repositories: {count2020MIT}")

#Apache
# 执行API调用并存储响应
url = 'https://api.github.com/search/repositories?q=created:2020&q=license:apache-2.0'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# 将API响应赋给一个变量
response_dict = r.json()
count2020Apache = response_dict['total_count']
print(f"Total repositories: {count2020Apache}")

#GPL3.0
# 执行API调用并存储响应
url = 'https://api.github.com/search/repositories?q=created:2020&q=license:gpl-3.0'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# 将API响应赋给一个变量
response_dict = r.json()
count2020GPL3 = response_dict['total_count']
print(f"Total repositories: {count2020GPL3}")

#GPL2.0
# 执行API调用并存储响应
url = 'https://api.github.com/search/repositories?q=created:2020&q=license:gpl-2.0'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# 将API响应赋给一个变量
response_dict = r.json()
count2020GPL2 = response_dict['total_count']
print(f"Total repositories: {count2020GPL2}")

#BSD3
# 执行API调用并存储响应
url = 'https://api.github.com/search/repositories?q=created:2020&q=license:bsd-3-clause'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# 将API响应赋给一个变量
response_dict = r.json()
count2020BSD3 = response_dict['total_count']
print(f"Total repositories: {count2020BSD3}")

#BSD2
# 执行API调用并存储响应
url = 'https://api.github.com/search/repositories?q=created:2020&q=license:bsd-2-clause'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# 将API响应赋给一个变量
response_dict = r.json()
count2020BSD2 = response_dict['total_count']
print(f"Total repositories: {count2020BSD2}")

#CCO
# 执行API调用并存储响应
url = 'https://api.github.com/search/repositories?q=created:2020&q=license:cc0-1.0'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# 将API响应赋给一个变量
response_dict = r.json()
count2020CCO = response_dict['total_count']
print(f"Total repositories: {count2020CCO}")

#AGPL
# 执行API调用并存储响应
url = 'https://api.github.com/search/repositories?q=created:2020&q=license:agpl-3.0'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# 将API响应赋给一个变量
response_dict = r.json()
count2020AGPL = response_dict['total_count']
print(f"Total repositories: {count2020AGPL}")

#LGPL
# 执行API调用并存储响应
url = 'https://api.github.com/search/repositories?q=created:2020&q=license:lgpl-3.0'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# 将API响应赋给一个变量
response_dict = r.json()
count2020LGPL = response_dict['total_count']
print(f"Total repositories: {count2020LGPL}")

#MPL
# 执行API调用并存储响应
url = 'https://api.github.com/search/repositories?q=created:2020&q=license:mpl-2.0'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# 将API响应赋给一个变量
response_dict = r.json()
count2020MPL = response_dict['total_count']
print(f"Total repositories: {count2020MPL}")
# Out:
# Status code: 200
# Total repositories: 7722368
# Status code: 200
# Total repositories: 2108780
# Status code: 200
# Total repositories: 2113727
# Status code: 200
# Total repositories: 475975
# Status code: 200
# Total repositories: 293619
# Status code: 200
# Total repositories: 109418
# Status code: 200
# Total repositories: 157917
# Status code: 200
# Total repositories: 191102
# Status code: 200
# Total repositories: 97982
# Status code: 200
# Total repositories: 92713

# %%
L2 = [count2020MIT,count2020Apache,count2020GPL3,count2020GPL2,count2020BSD3,count2020BSD2,count2020CCO,count2020AGPL,count2020LGPL,count2020MPL]
L1 = ['mit','apache-2.0','gpl-3.0','gpl-2.0','bsd-3-clause','bsd-2-clause','cc0-1.0','agpl-3.0','lgpl-3.0','mpl-2.0']

# %%
# 探索有关仓库的信息
repo_dicts = response_dict['items']
print(f"Repositories returned: {len(repo_dicts)}")

# 研究有关仓库的信息
print("\n部分仓库的信息:")
for repo_dict in repo_dicts:
    print(f"\nName: {repo_dict['name']}")
    print(f"Owner: {repo_dict['owner']['login']}")
    print(f"License: {repo_dict['license']}")
    print(f"Created: {repo_dict['created_at']}")
    print(f"Updated: {repo_dict['updated_at']}")
#可以看出这些都是使用了MIT许可证的项目
# Out:
# Repositories returned: 30
#
# 部分仓库的信息:
#
# Name: free-programming-books-zh_CN
# Owner: justjavac
# License: {'key': 'gpl-3.0', 'name': 'GNU General Public License v3.0', 'spdx_id': 'GPL-3.0', 'url': 'https://api.github.com/licenses/gpl-3.0', 'node_id': 'MDc6TGljZW5zZTk='}
# Created: 2013-11-04T01:59:19Z
# Updated: 2022-11-26T16:04:37Z
#
# Name: netdata
# Owner: netdata
# License: {'key': 'gpl-3.0', 'name': 'GNU General Public License v3.0', 'spdx_id': 'GPL-3.0', 'url': 'https://api.github.com/licenses/gpl-3.0', 'node_id': 'MDc6TGljZW5zZTk='}
# Created: 2013-06-17T18:39:10Z
# Updated: 2022-11-26T15:26:54Z
#
# Name: ansible
# Owner: ansible
# License: {'key': 'gpl-3.0', 'name': 'GNU General Public License v3.0', 'spdx_id': 'GPL-3.0', 'url': 'https://api.github.com/licenses/gpl-3.0', 'node_id': 'MDc6TGljZW5zZTk='}
# Created: 2012-03-06T14:58:02Z
# Updated: 2022-11-26T15:48:18Z
#
# Name: DeepLearning-500-questions
# Owner: scutan90
# ...

# %%
from plotly import offline

# 可视化
data = [{
    'type': 'bar',
    'x': L1,
    'y': L2,   
    'marker': {
        'color': 'rgb(100, 140, 200)',
        'line': {'width': 1, 'color': 'rgb(10, 10, 10)'}
    },
    'opacity': 0.5,
}]

my_layout = {
    'title': '2020GitHub开源许可证的使用',
    'titlefont': {'size': 20},
    'xaxis': {
        'title': '开源许可证',
        'titlefont': {'size': 20},
        'tickfont': {'size': 10},
    },
    'yaxis': {
        'title': '仓库数',
        'titlefont': {'size': 20},
        'tickfont': {'size': 10},
    },

}

fig = {'data': data, 'layout': my_layout}
offline.plot(fig, filename='python_repos.html')
# Out:
# 'python_repos.html'
