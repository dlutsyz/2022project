# %%
import requests

#MIT
# 执行API调用并存储响应
url = 'https://api.github.com/search/repositories?q=created:2016+license:mit'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# 将API响应赋给一个变量
response_dict = r.json()
count2016MIT = response_dict['total_count']
print(f"Total repositories: {count2016MIT}")

#MIT
# 执行API调用并存储响应
url = 'https://api.github.com/search/repositories?q=created:2017+license:mit'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# 将API响应赋给一个变量
response_dict = r.json()
count2017MIT = response_dict['total_count']
print(f"Total repositories: {count2017MIT}")

#MIT
# 执行API调用并存储响应
url = 'https://api.github.com/search/repositories?q=created:2018+license:mit'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# 将API响应赋给一个变量
response_dict = r.json()
count2018MIT = response_dict['total_count']
print(f"Total repositories: {count2018MIT}")

#MIT
# 执行API调用并存储响应
url = 'https://api.github.com/search/repositories?q=created:2019+license:mit'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# 将API响应赋给一个变量
response_dict = r.json()
count2019MIT = response_dict['total_count']
print(f"Total repositories: {count2019MIT}")

#MIT
# 执行API调用并存储响应
url = 'https://api.github.com/search/repositories?q=created:2020+license:mit'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# 将API响应赋给一个变量
response_dict = r.json()
count2020MIT = response_dict['total_count']
print(f"Total repositories: {count2020MIT}")

#MIT
# 执行API调用并存储响应
url = 'https://api.github.com/search/repositories?q=created:2021+license:mit'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# 将API响应赋给一个变量
response_dict = r.json()
count2021MIT = response_dict['total_count']
print(f"Total repositories: {count2021MIT}")

#MIT
# 执行API调用并存储响应
url = 'https://api.github.com/search/repositories?q=created:2022+license:mit'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# 将API响应赋给一个变量
response_dict = r.json()
count2022MIT = response_dict['total_count']
print(f"Total repositories: {count2022MIT}")





L2 = [count2016MIT,count2017MIT,count2017MIT,count2018MIT,count2019MIT,count2020MIT,count2021MIT,count2022MIT]
L1 = ['mit2016','mit2017','mit2018','mit2019','mit2020','mit2021','mit2022']



from plotly import offline

# 可视化
data = [{
    'type': 'bar',
    'x': L1,
    'y': L2,   
    'marker': {
        'color': 'rgb(100, 140, 200)',
        'line': {'width': 1, 'color': 'rgb(10, 10, 10)'}
    },
    'opacity': 0.5,
}]

my_layout = {
    'title': '2016-2022MIT开源许可证的使用',
    'titlefont': {'size': 20},
    'xaxis': {
        'title': 'MIT',
        'titlefont': {'size': 20},
        'tickfont': {'size': 10},
    },
    'yaxis': {
        'title': '仓库数',
        'titlefont': {'size': 20},
        'tickfont': {'size': 10},
    },

}

fig = {'data': data, 'layout': my_layout}
offline.plot(fig, filename='mit.html')
# Out:
# Status code: 200
# Total repositories: 572622
# Status code: 200
# Total repositories: 792625
# Status code: 200
# Total repositories: 976290
# Status code: 200
# Total repositories: 1055704
# Status code: 200
# Total repositories: 1705818
# Status code: 200
# Total repositories: 1874863
# Status code: 200
# Total repositories: 1781746
# 'mit.html'
