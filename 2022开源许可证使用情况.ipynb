# %%
import requests

#MIT
# 执行API调用并存储响应
url = 'https://api.github.com/search/repositories?q=created:2022&q=license:mit'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# 将API响应赋给一个变量
response_dict = r.json()
count2022MIT = response_dict['total_count']
print(f"Total repositories: {count2022MIT}")

#Apache
# 执行API调用并存储响应
url = 'https://api.github.com/search/repositories?q=created:2022&q=license:apache-2.0'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# 将API响应赋给一个变量
response_dict = r.json()
count2022Apache = response_dict['total_count']
print(f"Total repositories: {count2022Apache}")

#GPL3.0
# 执行API调用并存储响应
url = 'https://api.github.com/search/repositories?q=created:2022&q=license:gpl-3.0'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# 将API响应赋给一个变量
response_dict = r.json()
count2022GPL3 = response_dict['total_count']
print(f"Total repositories: {count2022GPL3}")

#GPL2.0
# 执行API调用并存储响应
url = 'https://api.github.com/search/repositories?q=created:2022&q=license:gpl-2.0'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# 将API响应赋给一个变量
response_dict = r.json()
count2022GPL2 = response_dict['total_count']
print(f"Total repositories: {count2022GPL2}")

#BSD3
# 执行API调用并存储响应
url = 'https://api.github.com/search/repositories?q=created:2022&q=license:bsd-3-clause'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# 将API响应赋给一个变量
response_dict = r.json()
count2022BSD3 = response_dict['total_count']
print(f"Total repositories: {count2022BSD3}")

#BSD2
# 执行API调用并存储响应
url = 'https://api.github.com/search/repositories?q=created:2022&q=license:bsd-2-clause'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# 将API响应赋给一个变量
response_dict = r.json()
count2022BSD2 = response_dict['total_count']
print(f"Total repositories: {count2022BSD2}")

#CCO
# 执行API调用并存储响应
url = 'https://api.github.com/search/repositories?q=created:2022&q=license:cc0-1.0'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# 将API响应赋给一个变量
response_dict = r.json()
count2022CCO = response_dict['total_count']
print(f"Total repositories: {count2022CCO}")

#AGPL
# 执行API调用并存储响应
url = 'https://api.github.com/search/repositories?q=created:2022&q=license:agpl-3.0'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# 将API响应赋给一个变量
response_dict = r.json()
count2022AGPL = response_dict['total_count']
print(f"Total repositories: {count2022AGPL}")

#LGPL
# 执行API调用并存储响应
url = 'https://api.github.com/search/repositories?q=created:2022&q=license:lgpl-3.0'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# 将API响应赋给一个变量
response_dict = r.json()
count2022LGPL = response_dict['total_count']
print(f"Total repositories: {count2022LGPL}")

#MPL
# 执行API调用并存储响应
url = 'https://api.github.com/search/repositories?q=created:2022&q=license:mpl-2.0'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# 将API响应赋给一个变量
response_dict = r.json()
count2022MPL = response_dict['total_count']
print(f"Total repositories: {count2022MPL}")



L2 = [count2022MIT,count2022Apache,count2022GPL3,count2022GPL2,count2022BSD3,count2022BSD2,count2022CCO,count2022AGPL,count2022LGPL,count2022MPL]
L1 = ['mit','apache-2.0','gpl-3.0','gpl-2.0','bsd-3-clause','bsd-2-clause','cc0-1.0','agpl-3.0','lgpl-3.0','mpl-2.0']



from plotly import offline

# 可视化
data = [{
    'type': 'bar',
    'x': L1,
    'y': L2,   
    'marker': {
        'color': 'rgb(100, 140, 200)',
        'line': {'width': 1, 'color': 'rgb(10, 10, 10)'}
    },
    'opacity': 0.5,
}]

my_layout = {
    'title': '2022GitHub开源许可证的使用',
    'titlefont': {'size': 20},
    'xaxis': {
        'title': '开源许可证',
        'titlefont': {'size': 20},
        'tickfont': {'size': 10},
    },
    'yaxis': {
        'title': '仓库数',
        'titlefont': {'size': 20},
        'tickfont': {'size': 10},
    },

}

fig = {'data': data, 'layout': my_layout}
offline.plot(fig, filename='2022.html')
# Out:
# Status code: 200
# Total repositories: 7720379
# Status code: 200
# Total repositories: 2114531
# Status code: 200
# Total repositories: 2112215
# Status code: 200
# Total repositories: 476035
# Status code: 200
# Total repositories: 293712
# Status code: 200
# Total repositories: 109440
# Status code: 200
# Total repositories: 158036
# Status code: 200
# Total repositories: 191238
# Status code: 200
# Total repositories: 97993
# Status code: 200
# Total repositories: 92769
# '2022.html'
